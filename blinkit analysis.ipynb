# %% [markdown]
# ## **DATA ANALYSIS PYTHON PROJECT - BLINKIT ANALYSIS**

# %% [markdown]
# **IMPORT LIBRARIES**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **IMPORT RAW DATA**

# %%
df = pd.read_csv("C:/Users/vanka/OneDrive/Documents/Blinkit EDA python project/blinkit_data.csv")

# %% [markdown]
# **SAMPLE DATA**

# %%
df.head(20)
# Out:
#    Item Fat Content Item Identifier              Item Type  \
# 0           Regular           FDX32  Fruits and Vegetables
# 1           Low Fat           NCB42     Health and Hygiene
# 2           Regular           FDR28           Frozen Foods
# 3           Regular           FDL50                 Canned
# 4           Low Fat           DRI25            Soft Drinks
# 5           low fat           FDS52           Frozen Foods
# 6           Low Fat           NCU05     Health and Hygiene
# 7           Low Fat           NCD30              Household
# 8           Low Fat           FDW20  Fruits and Vegetables
# 9           Low Fat           FDX25                 Canned
# 10               LF           FDX21            Snack Foods
# 11          Low Fat           NCU41     Health and Hygiene
# 12          Low Fat           FDL20  Fruits and Vegetables
# 13          Low Fat           NCR54              Household
# 14          Low Fat           FDH19                   Meat
# ...

# %%
df.tail(10)
# Out:
#      Item Fat Content Item Identifier              Item Type  \
# 8513          Regular           DRY23            Soft Drinks
# 8514          low fat           FDA11           Baking Goods
# 8515          low fat           FDK38                 Canned
# 8516          low fat           FDO38                 Canned
# 8517          low fat           FDG32  Fruits and Vegetables
# 8518          low fat           NCT53     Health and Hygiene
# 8519          low fat           FDN09            Snack Foods
# 8520          low fat           DRE13            Soft Drinks
# 8521              reg           FDT50                  Dairy
# 8522              reg           FDM58            Snack Foods
#
#       Outlet Establishment Year Outlet Identifier Outlet Location Type  \
# 8513                       1998            OUT027               Tier 3
# 8514                       1998            OUT027               Tier 3
# 8515                       1998            OUT027               Tier 3
# ...

# %% [markdown]
# **SIZE OF DATA**

# %%
print("size of data : ",df.shape)
# Out:
# size of data :  (8523, 12)

# %% [markdown]
# **FIELD INFO**

# %%
df.columns
# Out:
# Index(['Item Fat Content', 'Item Identifier', 'Item Type',
#        'Outlet Establishment Year', 'Outlet Identifier',
#        'Outlet Location Type', 'Outlet Size', 'Outlet Type', 'Item Visibility',
#        'Item Weight', 'Sales', 'Rating'],
#       dtype='object')

# %% [markdown]
# **DATA TYPES**

# %%
df.dtypes
# Out:
# Item Fat Content              object
# Item Identifier               object
# Item Type                     object
# Outlet Establishment Year      int64
# Outlet Identifier             object
# Outlet Location Type          object
# Outlet Size                   object
# Outlet Type                   object
# Item Visibility              float64
# Item Weight                  float64
# Sales                        float64
# Rating                       float64
# dtype: object

# %% [markdown]
# **DATA CLEANING**

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat' 'low fat' 'LF' 'reg']

# %%
df['Item Fat Content'] = df['Item Fat Content'].replace({'LF':'Low Fat',
                                                           'low fat':'Low Fat',
                                                           'reg':'Regular'
                                                         })

# %%
print(df['Item Fat Content'].unique())
# Out:
# ['Regular' 'Low Fat']

# %% [markdown]
# **TOTAL NULL VALUES**

# %%
print(df.isnull().sum())
# Out:
# Item Fat Content                0
# Item Identifier                 0
# Item Type                       0
# Outlet Establishment Year       0
# Outlet Identifier               0
# Outlet Location Type            0
# Outlet Size                     0
# Outlet Type                     0
# Item Visibility                 0
# Item Weight                  1463
# Sales                           0
# Rating                          0
# dtype: int64

# %% [markdown]
# WHEREVER ITEM WEIGHT IS NaN FILLING IT WITH THE MEAN OF THAT GROUP

# %%
df['Item Weight'] = df.groupby('Item Identifier')['Item Weight'].transform(
    lambda x: x.fillna(x.mean())
)

# %%
print(df.isnull().sum())
# Out:
# Item Fat Content             0
# Item Identifier              0
# Item Type                    0
# Outlet Establishment Year    0
# Outlet Identifier            0
# Outlet Location Type         0
# Outlet Size                  0
# Outlet Type                  0
# Item Visibility              0
# Item Weight                  4
# Sales                        0
# Rating                       0
# dtype: int64

# %%
df['Item Weight'] = df['Item Weight'].fillna(df['Item Weight'].mean())

# %%
print(df.isnull().sum())
# Out:
# Item Fat Content             0
# Item Identifier              0
# Item Type                    0
# Outlet Establishment Year    0
# Outlet Identifier            0
# Outlet Location Type         0
# Outlet Size                  0
# Outlet Type                  0
# Item Visibility              0
# Item Weight                  0
# Sales                        0
# Rating                       0
# dtype: int64

# %% [markdown]
# **NO DUPLICATE VALUES**

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# **BUSINESS REQUIREMENTS**

# %% [markdown]
# **KPI's REQUIREMENTS**

# %%
#Total Sales
total_sales = df['Sales'].sum()

#Average Sales
avg_sales = df['Sales'].mean()

#No of Items Sold
no_of_items_sold = df [ 'Sales'].count()

#Average Ratings
avg_ratings = df['Rating'].mean()


#Display
print(f"Total Sales: ${total_sales:,.0f}")
print(f"Average Sales: ${avg_sales:,.0f}")
print(f"No of Items Sold: {no_of_items_sold:,.0f}")
print(f"Average Ratings: {avg_ratings:,.0f}")
# Out:
# Total Sales: $1,201,681
# Average Sales: $141
# No of Items Sold: 8,523
# Average Ratings: 4

# %% [markdown]
# **CHARTS REQUIREMENTS**

# %% [markdown]
#   **TOTAL SALES BY FAT CONTENT**

# %%
sales_by_fat = df.groupby('Item Fat Content')['Sales'].sum()
ex = [0,0.1]
plt.pie(sales_by_fat, labels = sales_by_fat.index,
                             autopct = '%.1f%%',startangle = 90,explode = ex,shadow = True)
plt.title('sales by fat content')
plt.axis('equal')
plt.show()

# %% [markdown]
#   **TOTAL SALES BY ITEM TYPE**

# %%
sales_by_type = df.groupby('Item Type')['Sales'].sum().sort_values (ascending=False)

plt.figure(figsize=(10, 6))
bars = plt.bar(sales_by_type.index, sales_by_type.values)


plt.xticks(rotation=-90)
plt.xlabel('Item Type')
plt.ylabel('Total Sales')
plt.title('Total Sales by Item Type')


for bar in bars:
    plt.text(bar.get_x() + bar.get_width() / 2, bar.get_height(),
             f'{bar.get_height():,.0f}', ha='center', va='bottom', fontsize=8)
     

plt.tight_layout()
plt.show()

# %% [markdown]
#   **FAT CONTENT BY OUTLET FOR TOTAL SALE**

# %%
grouped =  df.groupby(['Outlet Location Type', 'Item Fat Content']) ['Sales'].sum().unstack()
grouped = grouped [['Regular', 'Low Fat']]

ax = grouped.plot(kind='bar', figsize=(8, 5), title='Outlet Tier by Item Fat Content')

plt.xlabel('Outlet Location Tier')
plt.ylabel('Total Sales')
plt.legend(title='Item Fat Content')

plt.tight_layout()
plt.show()

# %% [markdown]
#   **TOTAL SALES BY OUTLET ESTABLISHMENT**

# %%
sales_by_year = df.groupby('Outlet Establishment Year') ['Sales'].sum().sort_index()

plt.figure(figsize=(9,5))
plt.plot(sales_by_year.index, sales_by_year.values, marker='D', linestyle=':')

plt.xlabel('Outlet Establishment Year')
plt.ylabel('Total Sales')
plt.title('Outlet Establishment')

for x, y in zip(sales_by_year.index, sales_by_year.values):
         plt.text(x, y, f'{y:,.0f}', ha='center', va='bottom', fontsize=8)

plt.tight_layout()
plt.show()

# %% [markdown]
#  **SALES BY OUTLET SIZE**

# %%
sales_by_size = df.groupby('Outlet Size')['Sales'].sum()

plt.figure(figsize=(4, 4))
plt.pie(sales_by_size, labels=sales_by_size.index, autopct='%1.1f%%', startangle=90)
plt.title('Outlet Size')

plt.tight_layout()
plt.show()

# %% [markdown]
#  **SALES BY OUTLET LOCATION**

# %%
sales_by_location= df.groupby ('Outlet Location Type')['Sales'].sum().reset_index()

sales_by_location = sales_by_location.sort_values('Sales', ascending=False)

plt.figure(figsize=(10, 4)) # Smaller height, enough width

ax  = sns.barplot(x='Sales', y='Outlet Location Type', data=sales_by_location) 

plt.title('Total Sales by Outlet Location Type')
plt.xlabel('Total Sales')
plt.ylabel('Outlet Location Type')

plt.tight_layout() # Ensures Layout fits without scroll
plt.show()

# %% [markdown]
#  **top 10 most common categories**

# %%
top_categories = df['Item Type'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_categories.values, y=top_categories.index,color='orange')
plt.title('Top 10 Product Categories')
plt.xlabel('Number of Products')
plt.ylabel('Category')
plt.show()

# %% [markdown]
#  **Sales by Category (only top 5 categories)**

# %%
top5_cats = df['Item Type'].value_counts().head(5).index
df_top5 = df[df['Item Type'].isin(top5_cats)]

plt.figure(figsize=(10,6))
sns.boxplot(x='Item Type', y='Sales', data=df_top5)
plt.title('Sales Distribution by Top 5 Categories')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  **Top 5 Brands**

# %%
top5_brands = df['Item Type'].value_counts().head(5)

plt.figure(figsize=(8,8))
plt.pie(top5_brands.values, labels=top5_brands.index, autopct='%1.1f%%', startangle=140, colors=sns.color_palette('Set3'))
plt.title('Top 5 Brands Market Share')
plt.show()

# %% [markdown]
#  **SALES BY YEARS**

# %%
plt.figure(figsize=(8,5))
ax = sns.barplot(x='Outlet Establishment Year', y='Sales', data=df, color='skyblue',errorbar=None)  
 


for p in ax.patches:
    ax.annotate(f'{p.get_height():.1f}',           
                (p.get_x() + p.get_width() / 2., p.get_height()),  
                ha='center', va='bottom', fontsize=10, color='black')  


plt.title('Sales by Years')
plt.xlabel('Year')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
#  **RATINGS DISTRIBUTION**

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['Rating'], bins=20, kde=True, color='lightgreen')
plt.title('Ratings Distribution')
plt.xlabel('Ratings')
plt.ylabel('Count')
plt.show()

# %% [markdown]
#  **SALES VS RATINGS**

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='Rating', y='Sales', data=df, color='coral',hue = 'Sales')
plt.title('Sales vs Ratings')
plt.xlabel('Ratings')
plt.ylabel('Sales')
plt.show()

# %% [markdown]
#  **Top 10 Best-Selling Products**

# %%
top_products = df.groupby('Item Type')['Sales'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10,6))
sns.barplot(x=top_products.values, y=top_products.index,color = "green")
plt.title('Top 10 Best-Selling Products')
plt.xlabel('Total Sales')
plt.ylabel('Product Name')
plt.show()

# %% [markdown]
#  **CORRELATION BETWEEN SALES AND RATINGS**

# %%
plt.figure(figsize=(6,4))
sns.heatmap(df[['Sales', 'Rating']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation between Sales and Ratings')
plt.show()

# %% [markdown]
#  **COUNT OF OUTLETS BY LOCATION TYPE**

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Outlet Location Type', hue = "Outlet Size", palette='pastel')
plt.title('Count of Outlets by Location Type')
plt.xlabel('Location Type')
plt.ylabel('Number of Outlets')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
#  **COUNT OF OUTLETS BY SIZE**

# %%
plt.figure(figsize=(8,5))
sns.countplot(data=df, x='Outlet Size')
plt.title('Count of Outlets by Size')
plt.xlabel('Outlet Size')
plt.ylabel('Number of Outlets')
plt.show()

# %% [markdown]
#  **TOTAL SALES BY OUTLET TYPE**

# %%
outlet_sales = df.groupby('Outlet Type')['Sales'].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
sns.barplot(x=outlet_sales.values, y=outlet_sales.index, hue=outlet_sales.index,palette='viridis')
plt.title('Total Sales by Outlet Type')
plt.xlabel('Total Sales')
plt.ylabel('Outlet Type')
plt.show()
